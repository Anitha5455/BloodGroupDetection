# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/sample data of blood group types'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3806.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1943.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2768.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4025.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1314.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3467.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2497.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1909.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1455.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1806.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1891.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1814.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2028.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3961.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2815.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3039.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4415.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4078.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3088.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2107.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3457.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3535.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3841.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3715.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1623.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1965.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3286.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2885.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4376.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_327.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2663.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_178.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4304.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_270.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4682.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4603.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2106.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2493.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3326.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3663.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2977.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1370.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2000.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2043.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1738.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1719.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4355.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3356.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2650.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2638.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3381.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1863.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4043.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4500.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3144.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4628.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3846.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4298.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2371.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2491.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3970.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1640.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2011.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3213.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3746.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4509.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_101.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2613.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4723.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2396.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3141.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1506.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4498.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4299.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3499.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1113.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2681.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2184.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4629.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1451.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3212.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2068.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1624.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3922.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2531.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2573.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2820.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3172.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1532.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1253.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2747.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1106.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_0.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4504.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1938.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1606.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4256.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2098.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2654.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2944.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1839.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1973.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2356.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1403.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3633.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4559.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2148.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3052.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3828.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1724.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3062.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2214.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2867.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2554.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1466.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2324.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1110.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2794.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2063.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2124.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4684.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2888.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_22.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4713.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1246.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3786.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1791.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3059.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3069.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2386.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3851.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4274.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3148.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3723.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2980.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3316.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4266.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2057.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2013.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2230.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2718.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3414.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1010.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_428.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4116.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4277.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2836.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4721.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2037.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_307.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3772.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3094.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3992.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3095.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3164.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3674.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1324.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4424.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3058.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4000.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1452.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4510.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2592.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2145.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4083.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_331.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3372.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4650.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2030.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2757.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4434.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2523.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3047.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1721.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3066.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1085.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2479.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3805.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1697.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3643.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_389.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1386.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2538.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3159.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2534.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3964.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4641.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4651.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2508.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1621.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1449.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3698.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4140.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2790.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3421.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2745.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2575.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2612.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4729.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1583.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1015.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3704.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_402.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3087.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2103.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4255.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3832.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1718.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1241.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3829.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1663.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1068.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3685.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3242.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3778.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2263.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1086.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1905.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3260.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1289.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2879.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1007.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1939.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_383.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1953.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4245.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_356.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2258.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3561.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_453.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1479.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3582.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2843.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1269.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_202.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1509.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2627.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4297.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3149.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2017.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2287.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1364.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4672.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4017.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3518.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1155.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3959.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1558.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1139.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4461.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2933.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1034.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4887.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4922.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5444.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_791.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5624.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_685.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_860.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5221.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4787.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5595.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4899.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5955.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5857.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_92.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_947.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_600.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_481.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4860.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5605.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5725.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5821.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_86.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_579.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_547.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5425.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4989.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5463.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5377.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5467.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5996.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_548.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_806.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_986.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5181.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_699.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5816.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_97.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_530.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5454.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5496.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5569.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_795.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_673.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5945.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_491.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5216.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5310.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_563.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5227.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5891.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_67.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4835.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5802.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5475.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_738.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_727.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4772.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_658.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_883.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_66.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5039.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5263.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5738.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5628.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4878.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5545.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_890.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4764.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5296.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4862.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_528.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4895.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_690.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_550.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5882.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5654.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5086.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_98.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5397.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_782.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5339.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4744.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_618.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5294.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_765.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5128.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4844.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_627.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5281.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5407.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_555.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_637.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_966.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5442.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_757.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4806.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_931.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5949.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5393.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5674.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_629.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_912.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5757.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_640.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_652.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5228.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5359.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5710.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_611.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5006.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_613.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5878.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5218.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_927.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5998.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5048.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4943.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_743.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5754.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5972.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5511.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5222.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5550.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_675.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_865.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5801.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_615.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_830.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4745.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5091.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_606.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5794.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5907.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5819.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5787.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5245.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5174.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4914.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5666.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5991.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5318.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4903.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_739.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4833.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5252.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5582.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_708.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_584.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4755.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_73.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_857.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5373.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5088.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_821.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5287.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4993.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5224.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5590.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_973.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5658.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5482.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_63.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4851.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5797.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_74.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5501.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5840.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5137.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4991.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5982.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_621.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5778.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_824.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4808.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5596.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5015.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_89.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5789.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5662.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4900.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5743.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5688.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5935.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5175.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5280.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_811.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_793.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_704.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5953.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4766.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_835.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_767.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4902.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_974.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5003.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_659.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4972.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5177.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5587.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_93.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5446.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5920.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5255.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5275.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_83.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5838.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_596.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5323.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5385.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5530.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5536.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_84.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5848.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5556.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5602.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4820.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5489.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5613.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5072.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5191.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5428.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5063.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5713.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_770.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5573.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4775.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4904.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_56.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4934.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5997.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5182.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_494.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_862.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5378.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5126.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5523.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5782.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4822.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_509.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_599.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_923.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5724.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5102.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_545.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_805.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4792.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_741.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5733.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4782.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5201.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5243.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5676.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5901.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_526.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5469.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_955.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_680.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5143.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5037.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5306.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5614.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4742.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5355.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5379.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5195.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5398.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5695.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4801.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_558.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_924.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_603.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_810.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_877.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5108.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_917.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_873.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5085.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_605.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_731.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5410.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5669.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5434.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5533.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5361.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5984.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5334.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_960.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_913.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_99.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5611.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5927.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5784.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5659.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_512.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5490.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_841.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5779.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_711.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5014.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5279.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4804.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5185.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5898.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5007.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4996.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5322.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5568.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_5559.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_894.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4624.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1648.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3424.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_2328.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_3702.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1826.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1000.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_4360.BMP
# /content/drive/MyDrive/sample data of blood group types/A-/cluster_1_1744.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4762.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_313.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3249.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3287.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_518.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2720.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2064.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4010.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_5183.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3107.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3351.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4925.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2931.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2132.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2577.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_1379.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_388.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2981.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_5348.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_5109.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4352.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_1562.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2619.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4810.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2960.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_385.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4145.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3707.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2162.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_100.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2228.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_5023.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_37.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2988.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_107.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_1667.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_1030.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_1175.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3864.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_5076.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2183.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_2856.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_3924.BMP
# /content/drive/MyDrive/sample data of blood group types/AB+/cluster_4_4467.BMP
# ...
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4462.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_715.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_607.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5829.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_88.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4719.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4565.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_541.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4825.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4517.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_591.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5585.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5470.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5303.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4739.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_847.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5855.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5912.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5934.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_75.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5056.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5758.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_831.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_668.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4698.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5944.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_938.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5943.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5791.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5555.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5326.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_750.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_712.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5863.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_664.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5558.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5846.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5976.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_979.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_740.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4473.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5986.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_691.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5150.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5826.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4530.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5304.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4536.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5113.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4784.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5975.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4778.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5648.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5034.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5906.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_636.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5242.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_549.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5040.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4793.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5412.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_999.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5795.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4586.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4610.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4939.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5351.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_759.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5684.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_649.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_489.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4556.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5932.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5059.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4722.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_65.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_845.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_977.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4950.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_653.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5889.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4614.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5979.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_926.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5528.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4923.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_779.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_964.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_654.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_85.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5133.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_783.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5664.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_643.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4921.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_729.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_9.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_822.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5325.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5729.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4836.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5022.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4605.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5753.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4977.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5879.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5036.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_452.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_552.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_511.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5867.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_863.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4525.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_816.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_985.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4737.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5615.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_918.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5655.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5320.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4588.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_493.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5831.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5959.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5700.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5328.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5900.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5021.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_828.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4538.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4639.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5958.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4847.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4954.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5940.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_702.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5866.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5544.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_499.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_604.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4620.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5207.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5068.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_789.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5300.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_870.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5391.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5157.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_57.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_562.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5588.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_68.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_796.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5960.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_580.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_625.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4715.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5899.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5969.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5793.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5853.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5772.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4771.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5617.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5415.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5727.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5380.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5914.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_48.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_957.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4929.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_910.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_91.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5439.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_610.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_666.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4776.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4522.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5154.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5952.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5315.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_697.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4796.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5942.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_842.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_897.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_677.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5311.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5719.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5696.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_519.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_571.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_809.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5419.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4666.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5962.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_936.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_79.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5748.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4599.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5159.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4983.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5837.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_631.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_5500.BMP
# /content/drive/MyDrive/sample data of blood group types/O-/cluster_7_4858.BMP

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions
IMG_HEIGHT = 128
IMG_WIDTH = 128
BATCH_SIZE = 5

# Directory paths
train_dir = '/content/drive/MyDrive/sample data of blood group types'

# Data augmentation and preprocessing for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # Use 20% of the data for validation
)

# Train generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

# Validation generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Low accuracy model with Input layer
def create_low_accuracy_model():
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        tf.keras.layers.Conv2D(16, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(train_generator.num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Create the low accuracy model
low_acc_model = create_low_accuracy_model()

# Train the low accuracy model
history_low_acc = low_acc_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# Evaluate the low accuracy model
low_acc_eval = low_acc_model.evaluate(validation_generator)
print(f"Low Accuracy Model - Loss: {low_acc_eval[0]}, Accuracy: {low_acc_eval[1]}")
# Out:
# Found 4805 images belonging to 8 classes.
# Found 1197 images belonging to 8 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 2288s 2s/step - accuracy: 0.5261 - loss: 1.3005 - val_accuracy: 0.8192 - val_loss: 0.4290
# Epoch 2/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 155s 145ms/step - accuracy: 0.8648 - loss: 0.3601 - val_accuracy: 0.7916 - val_loss: 0.6236
# Epoch 3/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 103s 104ms/step - accuracy: 0.9201 - loss: 0.2125 - val_accuracy: 0.8201 - val_loss: 0.5135
# Epoch 4/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 140s 145ms/step - accuracy: 0.9705 - loss: 0.0789 - val_accuracy: 0.8544 - val_loss: 0.4133
# Epoch 5/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 142s 145ms/step - accuracy: 0.9853 - loss: 0.0495 - val_accuracy: 0.7808 - val_loss: 0.7686
# Epoch 6/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 101s 103ms/step - accuracy: 0.9833 - loss: 0.0391 - val_accuracy: 0.8603 - val_loss: 0.4339
# Epoch 7/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 99s 103ms/step - accuracy: 0.9786 - loss: 0.0662 - val_accuracy: 0.8000 - val_loss: 0.7301
# Epoch 8/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 142s 103ms/step - accuracy: 0.9863 - loss: 0.0348 - val_accuracy: 0.8192 - val_loss: 0.7545
# Epoch 9/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 142s 103ms/step - accuracy: 0.9968 - loss: 0.0063 - val_accuracy: 0.8628 - val_loss: 0.5176
# Epoch 10/10
# 961/961 ━━━━━━━━━━━━━━━━━━━━ 142s 103ms/step - accuracy: 1.0000 - loss: 1.9052e-04 - val_accuracy: 0.8619 - val_loss: 0.5578
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - accuracy: 0.8684 - loss: 0.5527
# Low Accuracy Model - Loss: 0.5568474531173706, Accuracy: 0.8621553778648376

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions
IMG_HEIGHT = 64
IMG_WIDTH = 64
BATCH_SIZE = 32

# Directory paths (adjust as needed)
train_dir = '/content/drive/MyDrive/dataset_blood_group'

# Data augmentation and preprocessing for training
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0,1]
    validation_split=0.2  # Use 20% of the data for validation
)

# Train generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'  # Training data subset
)

# Validation generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'  # Validation data subset
)

# High accuracy model: Deep CNN
def create_high_accuracy_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.5),  # Regularization to prevent overfitting
        tf.keras.layers.Dense(train_generator.num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Create the model
high_acc_model = create_high_accuracy_model()

# Train the model
history_high_acc = high_acc_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,  # Adjust the number of epochs based on your preference
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# Evaluate the model on validation data
high_acc_eval = high_acc_model.evaluate(validation_generator)
print(f"High Accuracy Model - Loss: {high_acc_eval[0]}, Accuracy: {high_acc_eval[1]}")
# Out:
# Found 4756 images belonging to 8 classes.
# Found 1186 images belonging to 8 classes.
# Epoch 1/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 70s 450ms/step - accuracy: 0.2957 - loss: 1.8022 - val_accuracy: 0.7686 - val_loss: 0.5885
# Epoch 2/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.8125 - loss: 0.5591 - val_accuracy: 0.7711 - val_loss: 0.5910
# Epoch 3/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 506ms/step - accuracy: 0.7646 - loss: 0.6301 - val_accuracy: 0.8150 - val_loss: 0.4834
# Epoch 4/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.7188 - loss: 0.5935 - val_accuracy: 0.8201 - val_loss: 0.4865
# Epoch 5/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 69s 467ms/step - accuracy: 0.8180 - loss: 0.4780 - val_accuracy: 0.8209 - val_loss: 0.4578
# Epoch 6/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.7500 - loss: 0.4531 - val_accuracy: 0.7652 - val_loss: 0.6605
# Epoch 7/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 64s 425ms/step - accuracy: 0.8483 - loss: 0.4004 - val_accuracy: 0.8302 - val_loss: 0.4483
# Epoch 8/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6875 - loss: 0.4906 - val_accuracy: 0.8412 - val_loss: 0.4241
# Epoch 9/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 84s 566ms/step - accuracy: 0.8459 - loss: 0.3837 - val_accuracy: 0.8530 - val_loss: 0.3998
# Epoch 10/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.7812 - loss: 0.5449 - val_accuracy: 0.8606 - val_loss: 0.3800
# Epoch 11/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 66s 447ms/step - accuracy: 0.8757 - loss: 0.3326 - val_accuracy: 0.8598 - val_loss: 0.3791
# Epoch 12/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8125 - loss: 0.3426 - val_accuracy: 0.8615 - val_loss: 0.3767
# Epoch 13/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 82s 555ms/step - accuracy: 0.8827 - loss: 0.2984 - val_accuracy: 0.8530 - val_loss: 0.3837
# Epoch 14/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9062 - loss: 0.2619 - val_accuracy: 0.8522 - val_loss: 0.3742
# Epoch 15/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 63s 427ms/step - accuracy: 0.8978 - loss: 0.2768 - val_accuracy: 0.8590 - val_loss: 0.4206
# Epoch 16/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.8750 - loss: 0.3693 - val_accuracy: 0.8606 - val_loss: 0.4073
# Epoch 17/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 68s 460ms/step - accuracy: 0.8976 - loss: 0.2579 - val_accuracy: 0.8530 - val_loss: 0.3727
# Epoch 18/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.9062 - loss: 0.3043 - val_accuracy: 0.8480 - val_loss: 0.3917
# Epoch 19/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 80s 540ms/step - accuracy: 0.9079 - loss: 0.2388 - val_accuracy: 0.8775 - val_loss: 0.3469
# Epoch 20/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9062 - loss: 0.2906 - val_accuracy: 0.8632 - val_loss: 0.3777
# Epoch 21/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 81s 550ms/step - accuracy: 0.9136 - loss: 0.2177 - val_accuracy: 0.8590 - val_loss: 0.3774
# Epoch 22/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9375 - loss: 0.1680 - val_accuracy: 0.8590 - val_loss: 0.3780
# Epoch 23/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 67s 450ms/step - accuracy: 0.9267 - loss: 0.2035 - val_accuracy: 0.8742 - val_loss: 0.3481
# Epoch 24/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9688 - loss: 0.1403 - val_accuracy: 0.8716 - val_loss: 0.3660
# Epoch 25/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 71s 435ms/step - accuracy: 0.9212 - loss: 0.1900 - val_accuracy: 0.8843 - val_loss: 0.3285
# Epoch 26/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 1.0000 - loss: 0.0641 - val_accuracy: 0.8716 - val_loss: 0.3612
# Epoch 27/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 72s 436ms/step - accuracy: 0.9355 - loss: 0.1670 - val_accuracy: 0.8556 - val_loss: 0.3992
# Epoch 28/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9688 - loss: 0.1518 - val_accuracy: 0.8590 - val_loss: 0.3901
# Epoch 29/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 82s 552ms/step - accuracy: 0.9403 - loss: 0.1518 - val_accuracy: 0.8902 - val_loss: 0.3485
# Epoch 30/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9688 - loss: 0.1115 - val_accuracy: 0.8910 - val_loss: 0.3572
# Epoch 31/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 119s 447ms/step - accuracy: 0.9489 - loss: 0.1385 - val_accuracy: 0.8598 - val_loss: 0.4506
# Epoch 32/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9688 - loss: 0.0992 - val_accuracy: 0.8657 - val_loss: 0.4217
# Epoch 33/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 74s 440ms/step - accuracy: 0.9482 - loss: 0.1315 - val_accuracy: 0.8784 - val_loss: 0.3753
# Epoch 34/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 1.0000 - loss: 0.0794 - val_accuracy: 0.8666 - val_loss: 0.4132
# Epoch 35/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 82s 551ms/step - accuracy: 0.9557 - loss: 0.1253 - val_accuracy: 0.8657 - val_loss: 0.3940
# Epoch 36/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.9688 - loss: 0.1039 - val_accuracy: 0.8581 - val_loss: 0.4168
# Epoch 37/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 118s 450ms/step - accuracy: 0.9592 - loss: 0.1067 - val_accuracy: 0.8801 - val_loss: 0.4268
# Epoch 38/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.9375 - loss: 0.1882 - val_accuracy: 0.8818 - val_loss: 0.4071
# Epoch 39/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 75s 473ms/step - accuracy: 0.9767 - loss: 0.0650 - val_accuracy: 0.8834 - val_loss: 0.4408
# Epoch 40/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.9688 - loss: 0.0377 - val_accuracy: 0.8818 - val_loss: 0.4802
# Epoch 41/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 68s 429ms/step - accuracy: 0.9723 - loss: 0.0765 - val_accuracy: 0.8742 - val_loss: 0.4432
# Epoch 42/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.8691 - val_loss: 0.4456
# Epoch 43/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 74s 428ms/step - accuracy: 0.9834 - loss: 0.0484 - val_accuracy: 0.8640 - val_loss: 0.6025
# Epoch 44/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.9688 - loss: 0.1174 - val_accuracy: 0.8590 - val_loss: 0.6386
# Epoch 45/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 74s 444ms/step - accuracy: 0.9713 - loss: 0.0780 - val_accuracy: 0.8682 - val_loss: 0.4788
# Epoch 46/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.9688 - loss: 0.1141 - val_accuracy: 0.8725 - val_loss: 0.4499
# Epoch 47/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 82s 554ms/step - accuracy: 0.9789 - loss: 0.0607 - val_accuracy: 0.8564 - val_loss: 0.4994
# Epoch 48/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8438 - loss: 0.2308 - val_accuracy: 0.8564 - val_loss: 0.5289
# Epoch 49/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 564ms/step - accuracy: 0.9794 - loss: 0.0627 - val_accuracy: 0.8581 - val_loss: 0.6312
# Epoch 50/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.9688 - loss: 0.0582 - val_accuracy: 0.8640 - val_loss: 0.6149
# Epoch 51/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 116s 447ms/step - accuracy: 0.9719 - loss: 0.0810 - val_accuracy: 0.8530 - val_loss: 0.6425
# Epoch 52/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.9375 - loss: 0.1542 - val_accuracy: 0.8370 - val_loss: 0.6973
# Epoch 53/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 62s 422ms/step - accuracy: 0.9861 - loss: 0.0400 - val_accuracy: 0.8699 - val_loss: 0.5498
# Epoch 54/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8733 - val_loss: 0.5364
# Epoch 55/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 84s 499ms/step - accuracy: 0.9853 - loss: 0.0415 - val_accuracy: 0.8666 - val_loss: 0.5941
# Epoch 56/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8691 - val_loss: 0.5918
# Epoch 57/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 558ms/step - accuracy: 0.9869 - loss: 0.0401 - val_accuracy: 0.8429 - val_loss: 0.5863
# Epoch 58/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.9375 - loss: 0.1428 - val_accuracy: 0.8539 - val_loss: 0.5419
# Epoch 59/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 64s 433ms/step - accuracy: 0.9874 - loss: 0.0333 - val_accuracy: 0.8733 - val_loss: 0.5450
# Epoch 60/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8750 - val_loss: 0.5499
# Epoch 61/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 64s 435ms/step - accuracy: 0.9945 - loss: 0.0144 - val_accuracy: 0.8640 - val_loss: 0.7159
# Epoch 62/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8674 - val_loss: 0.7065
# Epoch 63/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 66s 448ms/step - accuracy: 0.9864 - loss: 0.0313 - val_accuracy: 0.8640 - val_loss: 0.6184
# Epoch 64/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.9688 - loss: 0.0482 - val_accuracy: 0.8632 - val_loss: 0.6015
# Epoch 65/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 559ms/step - accuracy: 0.9808 - loss: 0.0536 - val_accuracy: 0.8657 - val_loss: 0.6345
# Epoch 66/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9688 - loss: 0.0685 - val_accuracy: 0.8606 - val_loss: 0.6099
# Epoch 67/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 62s 419ms/step - accuracy: 0.9777 - loss: 0.0599 - val_accuracy: 0.8378 - val_loss: 0.8182
# Epoch 68/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.8454 - val_loss: 0.7801
# Epoch 69/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 72s 407ms/step - accuracy: 0.9890 - loss: 0.0369 - val_accuracy: 0.8547 - val_loss: 0.6859
# Epoch 70/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.9375 - loss: 0.2741 - val_accuracy: 0.8581 - val_loss: 0.6763
# Epoch 71/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 82s 556ms/step - accuracy: 0.9845 - loss: 0.0458 - val_accuracy: 0.8530 - val_loss: 0.8097
# Epoch 72/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.8471 - val_loss: 0.8374
# Epoch 73/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 81s 546ms/step - accuracy: 0.9789 - loss: 0.0605 - val_accuracy: 0.8488 - val_loss: 0.6469
# Epoch 74/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.9688 - loss: 0.1120 - val_accuracy: 0.8530 - val_loss: 0.6685
# Epoch 75/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 142s 603ms/step - accuracy: 0.9884 - loss: 0.0347 - val_accuracy: 0.8539 - val_loss: 0.6945
# Epoch 76/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9688 - loss: 0.4885 - val_accuracy: 0.8556 - val_loss: 0.6569
# Epoch 77/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 565ms/step - accuracy: 0.9849 - loss: 0.0396 - val_accuracy: 0.8623 - val_loss: 0.7030
# Epoch 78/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.9688 - loss: 0.0237 - val_accuracy: 0.8590 - val_loss: 0.6958
# Epoch 79/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 142s 624ms/step - accuracy: 0.9946 - loss: 0.0197 - val_accuracy: 0.8395 - val_loss: 0.8724
# Epoch 80/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.9688 - loss: 0.0343 - val_accuracy: 0.8395 - val_loss: 0.8255
# Epoch 81/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 64s 434ms/step - accuracy: 0.9859 - loss: 0.0412 - val_accuracy: 0.8666 - val_loss: 0.6477
# Epoch 82/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.9688 - loss: 0.0824 - val_accuracy: 0.8590 - val_loss: 0.6786
# Epoch 83/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 73s 452ms/step - accuracy: 0.9774 - loss: 0.0681 - val_accuracy: 0.8590 - val_loss: 0.7280
# Epoch 84/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8623 - val_loss: 0.7344
# Epoch 85/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 71s 424ms/step - accuracy: 0.9939 - loss: 0.0199 - val_accuracy: 0.8530 - val_loss: 0.9124
# Epoch 86/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8530 - val_loss: 0.9243
# Epoch 87/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 81s 550ms/step - accuracy: 0.9861 - loss: 0.0420 - val_accuracy: 0.8657 - val_loss: 0.6864
# Epoch 88/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 1.0000 - loss: 2.6998e-04 - val_accuracy: 0.8623 - val_loss: 0.6929
# Epoch 89/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 63s 422ms/step - accuracy: 0.9947 - loss: 0.0190 - val_accuracy: 0.8514 - val_loss: 0.8309
# Epoch 90/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8505 - val_loss: 0.8310
# Epoch 91/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 62s 416ms/step - accuracy: 0.9832 - loss: 0.0459 - val_accuracy: 0.8269 - val_loss: 0.9456
# Epoch 92/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9688 - loss: 0.0849 - val_accuracy: 0.8395 - val_loss: 0.9154
# Epoch 93/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 80s 544ms/step - accuracy: 0.9812 - loss: 0.0616 - val_accuracy: 0.8556 - val_loss: 0.7816
# Epoch 94/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.8573 - val_loss: 0.7914
# Epoch 95/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 61s 411ms/step - accuracy: 0.9987 - loss: 0.0085 - val_accuracy: 0.8657 - val_loss: 0.8570
# Epoch 96/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 1.0000 - loss: 8.9658e-04 - val_accuracy: 0.8657 - val_loss: 0.8452
# Epoch 97/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 84s 490ms/step - accuracy: 0.9875 - loss: 0.0412 - val_accuracy: 0.8514 - val_loss: 0.9215
# Epoch 98/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8497 - val_loss: 0.9054
# Epoch 99/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 83s 559ms/step - accuracy: 0.9821 - loss: 0.0487 - val_accuracy: 0.8480 - val_loss: 0.8772
# Epoch 100/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 0.8463 - val_loss: 0.8597
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.8306 - loss: 0.9500
# High Accuracy Model - Loss: 0.8582916259765625, Accuracy: 0.84654301404953

# %%
high_acc_model.save("one_HIGH_accuracy_blood_group_model11.keras")
print("High accuracy model saved successfully!")
# Out:
# High accuracy model saved successfully!

# %%
model_save_path = "/content/drive/MyDrive/one_HIGH_accuracy_blood_group_model11.keras"

# %%
model_save_path = "/content/drive/MyDrive/My_model_blood_group_model.keras"
high_acc_model.save(model_save_path)
print(f"Model saved successfully at {model_save_path}")
# Out:
# Model saved successfully at /content/drive/MyDrive/My_model_blood_group_model.keras

# %%
history_high_acc

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
def plot_accuracy(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# Call the function to display the accuracy graph
plot_accuracy(history_high_acc)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Predict on the validation set
Y_pred = high_acc_model.predict(validation_generator, steps=validation_generator.samples // BATCH_SIZE, verbose=1)

# Step 2: Convert predictions to class labels
y_pred = np.argmax(Y_pred, axis=1)  # Convert probabilities to class indices

# Step 3: Get the true labels
y_true = validation_generator.classes

# Flatten both y_true and y_pred to ensure they have the same shape
y_true = y_true[:len(y_pred)]  # In case there are extra samples in validation

# Ensure the shapes are now correct and match
assert y_true.shape[0] == y_pred.shape[0], "Mismatch between true and predicted labels"

# Step 4: Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Step 5: Normalize the confusion matrix (optional, if you'd like to see percentages instead of counts)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Step 6: Plot the confusion matrix using a heatmap
plt.figure(figsize=(10,7))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

# Step 7: Add labels and title for better visualization
plt.xlabel('Predicted Blood Group')
plt.ylabel('True Blood Group')
plt.title('Normalized Confusion Matrix - Blood Group Prediction')

# Show the plot
plt.show()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step

# %%
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d5dd75f59e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 244ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report

conf_matrix = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Define blood_groups here
blood_groups = ['A-', 'A+', 'AB-', 'AB+', 'B-', 'B+', 'O-', 'O+']

# Optional: Classification Report
print("\nClassification Report:")
print(classification_report(y_test, predicted_labels, target_names=blood_groups))
# Out:
# Confusion Matrix:
# [[117   0   7   0   0   0   9   2]
#  [  0 195   4   0   2   2  13   0]
#  [  1   1 130   0   2   0   4   0]
#  [  0  11   1 108   4   3   2   3]
#  [  0   7   2   3 113   4   0   0]
#  [  0   8   0   1   2 129   0   0]
#  [  2   4   6   0   0   0 160   0]
#  [  4   1  11   0   2   0  12 108]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           A-       0.94      0.87      0.90       135
#           A+       0.86      0.90      0.88       216
#          AB-       0.81      0.94      0.87       138
#          AB+       0.96      0.82      0.89       132
#           B-       0.90      0.88      0.89       129
#           B+       0.93      0.92      0.93       140
#           O-       0.80      0.93      0.86       172
#           O+       0.96      0.78      0.86       138
#
#     accuracy                           0.88      1200
#    macro avg       0.90      0.88      0.88      1200
# weighted avg       0.89      0.88      0.88      1200

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os # Import the os module

def gabor_filter(img, ksize=5, sigma=4.0, theta=np.pi/4, lambd=10.0, gamma=0.5, psi=0):
    gabor_kernel = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
    filtered_img = cv2.filter2D(img, cv2.CV_8UC3, gabor_kernel)
    return filtered_img

# Load a sample fingerprint image
# Check if the image file exists
image_path = '/content/drive/MyDrive/sample data of blood group types'  # Update with actual image path

if os.path.exists(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Check if the image was loaded successfully
    if img is not None:
        filtered_img = gabor_filter(img)

        # Show the original and filtered image
        plt.figure(figsize=(10,5))
        plt.subplot(1,2,1), plt.imshow(img, cmap='gray'), plt.title('Original')
        plt.subplot(1,2,2), plt.imshow(filtered_img, cmap='gray'), plt.title('Gabor Filtered')
        plt.show()
    else:
        print(f"Error: Could not load image from {image_path}")
else:
    print(f"Error: Image file not found at {image_path}")
# Out:
# Error: Could not load image from /content/drive/MyDrive/sample data of blood group types

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import Sequence
import cv2
import numpy as np

class GaborImageDataGenerator(Sequence):
    def __init__(self, generator):
        self.generator = generator

    def __len__(self):
        return len(self.generator)

    def __getitem__(self, idx):
        batch_x, batch_y = self.generator[idx]
        batch_x = np.array([gabor_filter(img) for img in batch_x])
        return batch_x, batch_y

# Use ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(64, 64), batch_size=32, class_mode='categorical', subset='training')

# Apply Gabor filtering
train_generator = GaborImageDataGenerator(train_generator)
# Out:
# Found 4805 images belonging to 8 classes.

# %%
from tensorflow.keras.models import load_model

model_path = "/content/drive/MyDrive/My_model_blood_group_model.keras"
model = load_model(model_path)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import tensorflow as tf
import os

# Load the pre-trained model
model_path = "/content/drive/MyDrive/My_model_blood_group_model.keras"
high_acc_model = tf.keras.models.load_model(model_path)

# Define image dimensions (Ensure this matches the model input size)
IMG_HEIGHT = 64
IMG_WIDTH = 64

# Function to preprocess an image and make a prediction
def predict_blood_group(image_path):
    # Load and preprocess the image
    img = image.load_img(image_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions for model input
    img_array /= 255.0  # Normalize pixel values to [0,1]

    # Make a prediction
    predictions = high_acc_model.predict(img_array)

    # Get the predicted class index
    predicted_class = np.argmax(predictions)

    # Get the class label mapping
    class_labels = {
        0: "A+",
        1: "A-",
        2: "AB+",
        3: "AB-",
        4: "B+",
        5: "B-",
        6: "O+",
        7: "O-"
    }

    # Get the predicted blood group
    predicted_blood_group = class_labels.get(predicted_class, "Unknown")
    print(f"The predicted blood group is: {predicted_blood_group}")

# Example usage:
image_path = "/content/drive/MyDrive/Testing Images/Testing/A+/cluster_0_1001.BMP"  # Update with actual image path
predict_blood_group(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# The predicted blood group is: A+

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import tensorflow as tf
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the pre-trained model
model_path = "/content/drive/MyDrive/My_model_blood_group_model.keras"
high_acc_model = tf.keras.models.load_model(model_path)

# Define image dimensions (Ensure this matches the model input size)
IMG_HEIGHT = 64
IMG_WIDTH = 64

# Define blood group labels
blood_groups = ['A-', 'A+', 'AB-', 'AB+', 'B-', 'B+', 'O-', 'O+']

# Function to preprocess an image and make a prediction
def predict_blood_group(image_path):
    img = image.load_img(image_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = high_acc_model.predict(img_array)
    predicted_class = np.argmax(predictions)
    return predicted_class  # Return the predicted class index

# Path to your testing images directory
test_dir = "/content/drive/MyDrive/sample data of blood group types"  # Update with your test data path

# Get a list of all image files in the test directory and their true labels
image_paths = []
true_labels = []
for blood_group in blood_groups:
    blood_group_dir = os.path.join(test_dir, blood_group)
    for filename in os.listdir(blood_group_dir):
        image_paths.append(os.path.join(blood_group_dir, filename))
        true_labels.append(blood_groups.index(blood_group))  # Get index of blood group

# Make predictions for all test images
predicted_labels = []
for image_path in image_paths:
    predicted_labels.append(predict_blood_group(image_path))

# Generate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Normalize confusion matrix (optional)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=blood_groups, yticklabels=blood_groups)
plt.xlabel('Predicted Blood Group')
plt.ylabel('True Blood Group')
plt.title('Normalized Confusion Matrix - Blood Group Prediction')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
